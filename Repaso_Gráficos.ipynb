# %% [markdown]
# <a href="https://colab.research.google.com/github/qwertypicass/BigD_KonradLorenz/blob/Camilo_Cruz/Repaso_Gr%C3%A1ficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# REPASO CLASE
# - CÓMO SUBIR BASES DE DATOS
# - GRÁFICOS I PARTE

# %%
# Ejemplo del primer método para cargar información
# 1 paso en la carpeta de la izquierda
# 2 paso Activar unidad de drive
# 3 No gracias
# Me arroja un link para conectar mi drive con colab

# %%
# Este es el link del paso anterior
# ejecuto está celda
# conecto con el drive
# sigo los pasos para conectar mi cuenta de google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# una vez linkeada actualizo la carpeta para que me salga Drive
# Dentro de esa carpeta Drive busco la base de datos que quiero trabajar
# cuando la encuentre le doy click derecho y copiar ruta de acceso
# ahora creo una variable que se llame URL que contenga el link

URL = "/content/drive/MyDrive/Colab Notebooks/Electric_Vehicle_Population_Data.csv"

# Ejecuto la celda y ya queda cargado el link con la variable URL

# %%
# ahora necesito traer la biblioteca que me va ayudar con el análisis de datos PANDAS para eso la importo

import pandas as pd

# ejecuto para importarlo

# %%
# una vez tenga el link con la variable y la biblioteca de pandas debo traer la base de datos para trabajarla
# Df = dataframe o base de datos ojo
# creo una variable df que lea mi base de datos OJO

df = pd.read_csv(URL)

# Si es una archivo con varias hojas lo que hago para elegir la que voy a trabajar es después de la variable URL
# pongo una coma y añado "sheet_name=(acá nombre de la pestaña)"
# ya tengo cargada la variable y le pedí que me la leyera con pandas ahora puedo hacer un head para ver si cargo bien

# %%
#Comando para llamar la base de datos o dataframe
df.head(1)
# Out:
#    VIN (1-10)  County    City State  Postal Code  Model Year     Make  \
# 0  KM8KMDAF1N  Yakima  Yakima    WA      98902.0        2022  HYUNDAI
#
#      Model           Electric Vehicle Type  \
# 0  IONIQ 5  Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0  Eligibility unknown as battery range has not b...               0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  14.0       195331062
#
#                  Vehicle Location Electric Utility  2020 Census Tract
# 0  POINT (-120.524012 46.5973939)       PACIFICORP       5.307700e+10

# %%
# ejemplo con una segunda base de datos

URL2 = "/content/drive/MyDrive/Colab Notebooks/nacimientos.csv"

# %%
df1 = pd.read_csv(URL2)

# %%
df1.head()
# Out:
#   Departamento Nacimiento Municipio Nacimiento     Área Nacimiento     Género  \
# 0         VALLE DEL CAUCA                 CALI  CABECERA MUNICIPAL  MASCULINO
# 1         VALLE DEL CAUCA                 CALI  CABECERA MUNICIPAL   FEMENINO
# 2         VALLE DEL CAUCA                 CALI  CABECERA MUNICIPAL  MASCULINO
# 3         VALLE DEL CAUCA                 CALI  CABECERA MUNICIPAL   FEMENINO
# 4         VALLE DEL CAUCA                 CALI  CABECERA MUNICIPAL   FEMENINO
#
#    Peso  Talla     Fecha de Nacimiento Hora de Nacimiento  \
# 0  3672     52  01/01/2016 12:00:00 AM           22:43:00
# 1  3720     52                     NaN           12:30:00
# 2  1970     48  10/01/2016 12:00:00 AM           11:55:00
# 3  3100     50  10/01/2016 12:00:00 AM           12:59:00
# 4  3320     50                     NaN            7:49:00
#
#   Parto Atendido por...  Tiempo de Gestación  ...  Rural Disperso  \
# 0                MÉDICO                   39  ...             NaN
# ...

# %% [markdown]
# GRÁFICOS

# %% [markdown]
# para trabajar los gráficos se usan nuevos paquetes:
#  R = GGplot y en el caso de python = Matplotlib + Seaborn.

# %% [markdown]
# Para poder trabajar con los paquetes de gráficos lo pirmero que se t iene que hacer es importarlo, como se hace con pandas.
#
# el comando es
# import seaborn as sns
# import matplotlib.pyplot as plt
# *ambos se deben traer para poder trabajar las gráficas

# %%
#acá estoy importantando las bibliotecas para poder trabajar en el análisis de datos de manera gráfica


import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Este es el paquete que permite trabajar R
# !pip install rpy2[robjects,pandas]
# Out:
# ...
# WARNING: rpy2 3.4.2 does not provide the extra 'robjects'
# ...

# %%
# !pip install rpy2==3.5.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rpy2: filename=rpy2-3.5.1-cp310-cp310-linux_x86_64.whl size=314937 sha256=0baf499d226deab27e5cf0c3ea573a117fe6d86b0764a9c931a73e9bb310b35e
#   Stored in directory: /root/.cache/pip/wheels/73/a6/ff/4e75dd1ce1cfa2b9a670cbccf6a1e41c553199e9b25f05d953
# Successfully built rpy2
# ...
#   Attempting uninstall: rpy2
#     Found existing installation: rpy2 3.4.2
#     Uninstalling rpy2-3.4.2:
#       Successfully uninstalled rpy2-3.4.2
# ...

# %%
# activate R magic
# %load_ext rpy2.ipython

# %%
# y esto por último son las librerías que vamos a usar para los ejemplos de las gráficas
# estás son de R
# %%R
install.packages("gapminder")
install.packages("dslabs")
install.packages("NHANES")
install.packages("tidyverse")
install.packages("GGally")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/gapminder_1.0.0.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 2202445 bytes (2.1 MB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...

# %%
# acá lo que hago es cargar las librerías que exporte anteriormente

# %%R

library("tidyverse")
library(gapminder)
library(dplyr)
library(dslabs)
library(NHANES)
data(NHANES)
data(heights)
data(murders)
data(gapminder)
library("ggplot2")
library("GGally")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:
# Attaching package: ‘dslabs’
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: The following object is masked from ‘package:gapminder’:
#
#     gapminder
#
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %%
# hay un comando que nos dice en que base de datos se está trabajando
# en R el comando es %%R ls() y cuando lo corra me dice que bases de datos tengo cargadas
# ahora, para ver en python el comando es !ls()

# %%
# %%R
# ls()
# Out:
# [1] "gapminder" "heights"   "murders"   "NHANES"    "oecd"      "opec"

# %%
# !ls()
# Out:
# /bin/bash: -c: line 2: syntax error: unexpected end of file

# %%
# %%R
# print(opec%>%head())
# Out:
# [1] "Algeria" "Angola"  "Ecuador" "Iran"    "Iraq"    "Kuwait"

# %%
# hay un truco valioso y es el poder importar las bibliotecas entre lenguajes, más adelante se aclara el porqué
# para hacer eso lo que debo hacer es %%R -i nombre de la variable (este es de python hacía R)

# %R  data()
