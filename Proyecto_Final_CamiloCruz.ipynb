# %% [markdown]
# <a href="https://colab.research.google.com/github/qwertypicass/BigD_KonradLorenz/blob/Camilo_Cruz/Proyecto_Final_CamiloCruz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROYECTO FINAL
# Camilo Andrés Cruz
# Tema: Venta pollo
# Pregunta problema: ¿Qué diferencia existe en el tipo de consumo por cortes en las diferentes regiones del país?

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
URL = '/content/drive/MyDrive/Colab Notebooks/BSC Pollo (YTD Diciembre 2022).xlsx'

# %%
import pandas as pd

# %%
df = pd.read_excel(URL, sheet_name ='Base (Productos y Marcas)')

# %%
df.describe()
# Out:
#                  ID  Almacenes Vendiendo EPOS (Anterior)  \
# count  3.378000e+03                          3378.000000
# mean   1.011943e+06                             9.763470
# std    8.298419e+05                            11.454588
# min    3.438000e+03                             0.000000
# 25%    3.950920e+05                             2.000000
# 50%    8.215960e+05                             5.000000
# 75%    1.569207e+06                            13.000000
# max    3.332077e+06                            62.000000
#
#        Almacenes Vendiendo EPOS (Reciente)  Unidades (EPOS) (Anterior)  \
# count                          3378.000000                3.378000e+03
# mean                              9.317052                5.961821e+03
# std                              11.244259                3.257466e+04
# min                               0.000000                0.000000e+00
# 25%                               1.000000                2.700000e+01
# 50%                               5.000000                4.395000e+02
# 75%                              13.000000                2.685750e+03
# max                              60.000000                1.187229e+06
#
#        Unidades (EPOS) (Reciente)  Ventas $ (EPOS) (Anterior)  \
# count                3.378000e+03                3.378000e+03
# mean                 7.369531e+03                6.914306e+07
# std                  7.155597e+04                2.463581e+08
# min                  0.000000e+00                0.000000e+00
# 25%                  1.300000e+01                3.337090e+05
# 50%                  3.670000e+02                5.806714e+06
# 75%                  2.536250e+03                3.699857e+07
# max                  2.842089e+06                5.435111e+09
#
#        Ventas $ (EPOS) (Reciente)  Referencia interna  \
# count                3.378000e+03        7.950000e+02
# mean                 8.396152e+07        4.110460e+07
# std                  3.139968e+08        5.272618e+04
# min                  0.000000e+00        4.101011e+07
# 25%                  1.651545e+05        4.105292e+07
# 50%                  5.480120e+06        4.112082e+07
# 75%                  4.096179e+07        4.113382e+07
# max                  7.159843e+09        4.119132e+07
#
#        User Defined Launch Date
# count                       0.0
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN

# %%
df.head()
# Out:
#   Nivel de Análisis         Grupo de Productos     ID  \
# 0         Productos  POLLO - 03830038035030020  22247
# 1         Productos  POLLO - 03830038035030020  24697
# 2         Productos  POLLO - 03830038035030020  24697
# 3         Productos  POLLO - 03830038035030020  27304
# 4         Productos  POLLO - 03830038035030020  27304
#
#                                Nombre de producto       Banner        Región  \
# 0  Pierna Pernil De Pollo IMarin FRESCAMPO 1000 G  SUPER INTER  Eje Cafetero
# 1                     Filete Contramuslo* SM 1 KG  SUPER INTER          Cali
# 2                     Filete Contramuslo* SM 1 KG  SUPER INTER  Eje Cafetero
# 3    Of Pechuga Campesina Marinada PROMOCION 1 KG  SUPER INTER          Cali
# 4    Of Pechuga Campesina Marinada PROMOCION 1 KG  SUPER INTER  Eje Cafetero
#
#    Almacenes Vendiendo EPOS (Anterior)  Almacenes Vendiendo EPOS (Reciente)  \
# 0                                   13                                    4
# 1                                   19                                   17
# 2                                    1                                    1
# 3                                   11                                    5
# 4                                    5                                    2
#
#    Unidades (EPOS) (Anterior)  Unidades (EPOS) (Reciente)  ...  \
# 0                       13227                        8128  ...
# 1                          47                          36  ...
# 2                           1                           1  ...
# 3                          11                          10  ...
# 4                           8                           2  ...
#
#    LINEA DE PRODUCTOS +BIOS     LÍNEA OPAV  - MARCA GRUPOS  \
# 0                  ORIGINAL  Original         MARCA PROPIA
# 1                       NaN       NaN            SIN MARCA
# 2                       NaN       NaN            SIN MARCA
# 3                       NaN       NaN            SIN MARCA
# 4                       NaN       NaN            SIN MARCA
#
#   OPAV  - PROVEEDOR GRUPOS     OPAV- CATEGORIA POLLO            OPAV-CORTES  \
# 0            SIN PROVEEDOR     POLLO BLANCO ATENDIDO                 PERNIL
# 1            SIN PROVEEDOR     POLLO BLANCO ATENDIDO  FILETE DE CONTRAMUSLO
# 2            SIN PROVEEDOR     POLLO BLANCO ATENDIDO  FILETE DE CONTRAMUSLO
# 3            SIN PROVEEDOR  POLLO CAMPESINO ATENDIDO                PECHUGA
# 4            SIN PROVEEDOR  POLLO CAMPESINO ATENDIDO                PECHUGA
#
#   Referencia interna    TIPO DE POLLO User Defined Launch Date  \
# 0         41154221.0     POLLO BLANCO                      NaN
# 1                NaN     POLLO BLANCO                      NaN
# 2                NaN     POLLO BLANCO                      NaN
# 3                NaN  POLLO CAMPESINO                      NaN
# 4                NaN  POLLO CAMPESINO                      NaN
#
#        Valor agregado
# 0  Sin valor agregado
# 1  Sin valor agregado
# 2  Sin valor agregado
# 3  Sin valor agregado
# 4  Sin valor agregado
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3378 entries, 0 to 3377
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Nivel de Análisis                    3378 non-null   object
#  1   Grupo de Productos                   3378 non-null   object
#  2   ID                                   3378 non-null   int64
#  3   Nombre de producto                   3378 non-null   object
#  4   Banner                               3378 non-null   object
#  5   Región                               3378 non-null   object
#  6   Almacenes Vendiendo EPOS (Anterior)  3378 non-null   int64
#  7   Almacenes Vendiendo EPOS (Reciente)  3378 non-null   int64
#  8   Unidades (EPOS) (Anterior)           3378 non-null   int64
#  9   Unidades (EPOS) (Reciente)           3378 non-null   int64
#  10  Ventas $ (EPOS) (Anterior)           3378 non-null   float64
#  11  Ventas $ (EPOS) (Reciente)           3378 non-null   float64
#  12  CONDICIONES ESPECIALES               3378 non-null   object
#  13  CONSERVACION                         3378 non-null   object
#  14  CORTES                               3378 non-null   object
#  15  FAMILIAR                             3378 non-null   object
#  16  LINEA DE PRODUCTOS +BIOS             873 non-null    object
#  17  LÍNEA                                873 non-null    object
#  18  OPAV  - MARCA GRUPOS                 3378 non-null   object
#  19  OPAV  - PROVEEDOR GRUPOS             3378 non-null   object
#  20  OPAV- CATEGORIA POLLO                3378 non-null   object
#  21  OPAV-CORTES                          3378 non-null   object
#  22  Referencia interna                   795 non-null    float64
#  23  TIPO DE POLLO                        3378 non-null   object
#  24  User Defined Launch Date             0 non-null      float64
#  25  Valor agregado                       3378 non-null   object
# dtypes: float64(4), int64(5), object(17)
# memory usage: 686.3+ KB

# %%
resumen_por_region = df.groupby('Región')['Unidades (EPOS) (Reciente)'].describe()
print(resumen_por_region)
# Out:
#                       count          mean            std  min   25%    50%  \
# Región
# Bogota                942.0   6249.563694   18492.664764  0.0  21.0  584.0
# Cali                  518.0  13432.117761  128352.449301  0.0   5.0  280.5
# Costa                 531.0   5412.512241   19399.563332  0.0   8.0  230.0
# Eje Cafetero          500.0  10289.026000  127500.501259  0.0   3.0  140.0
# Medellin              679.0   5130.765832   12051.809407  0.0  52.0  818.0
# Santanderes y Boyacá  208.0   2629.822115    6061.009364  0.0   6.0  216.0
#
#                           75%        max
# Región
# Bogota                4385.00   226517.0
# Cali                  1979.50  2842089.0
# Costa                 1836.50   168970.0
# Eje Cafetero           860.75  2809851.0
# Medellin              3849.00   129512.0
# Santanderes y Boyacá  1899.75    43619.0

# %%
# Calcular estadísticas resumen de unidades vendidas por región
resumen_por_region = df.groupby('Región')['Unidades (EPOS) (Reciente)'].describe()
resumen_por_region = resumen_por_region.apply(lambda x: round(x, 2) if x.name != 'count' else x)
print(resumen_por_region)
# Out:
#                       count      mean        std  min   25%    50%      75%  \
# Región
# Bogota                942.0   6249.56   18492.66  0.0  21.0  584.0  4385.00
# Cali                  518.0  13432.12  128352.45  0.0   5.0  280.5  1979.50
# Costa                 531.0   5412.51   19399.56  0.0   8.0  230.0  1836.50
# Eje Cafetero          500.0  10289.03  127500.50  0.0   3.0  140.0   860.75
# Medellin              679.0   5130.77   12051.81  0.0  52.0  818.0  3849.00
# Santanderes y Boyacá  208.0   2629.82    6061.01  0.0   6.0  216.0  1899.75
#
#                             max
# Región
# Bogota                 226517.0
# Cali                  2842089.0
# Costa                  168970.0
# Eje Cafetero          2809851.0
# Medellin               129512.0
# Santanderes y Boyacá    43619.0
